# %%
import requests
import pandas as pd
import numpy as np
from io import StringIO

# %%
url_passengers = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000001/~latest.csv?lang=en"
url_gm = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000002/~latest.csv"
url_op = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000003/~latest.csv"

# %%
# Send HTTP GET request
response = requests.get(url_passengers)

# Check if the request was successful
if response.status_code == 200:
    # Read CSV data using pandas
    csv_data = StringIO(response.content.decode("utf-8"))
    data_t = pd.read_csv(csv_data)
else:
    print("Failed to retrieve data. Status code:", response.status_code)

# %%
df = data_t.copy(deep=True)

# %%
df.drop(columns=df.columns[df.columns.str.endswith('#es')], inplace=True)

# %%
df['AEROPUERTO_ESCALA_CODE']
# Out:
# 0               CV
# 1               CV
# 2               CV
# 3               CV
# 4               CV
#             ...
# 2963515    SE_ESMS
# 2963516    SE_ESMS
# 2963517    SE_ESMS
# 2963518    SE_ESMS
# 2963519    SE_ESMS
# Name: AEROPUERTO_ESCALA_CODE, Length: 2963520, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2963520 entries, 0 to 2963519
# Data columns (total 16 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   SERVICIO_AEREO#en                object
#  1   SERVICIO_AEREO_CODE              object
#  2   MEDIDAS#en                       object
#  3   MEDIDAS_CODE                     object
#  4   MOVIMIENTO_AERONAVE#en           object
#  5   MOVIMIENTO_AERONAVE_CODE         object
#  6   TIME_PERIOD#en                   object
#  7   TIME_PERIOD_CODE                 object
#  8   AEROPUERTO_BASE#en               object
#  9   AEROPUERTO_BASE_CODE             object
#  10  AEROPUERTO_ESCALA#en             object
#  11  AEROPUERTO_ESCALA_CODE           object
#  12  OBS_VALUE                        float64
#  13  ESTADO_OBSERVACION#en            object
#  14  ESTADO_OBSERVACION_CODE          object
#  15  CONFIDENCIALIDAD_OBSERVACION#en  float64
# dtypes: float64(2), object(14)
# memory usage: 361.8+ MB

# %% [markdown]
# Steps to getting the airports right:
# 1) Delete countries, autonomous communities and "Rest of"/"Remain of"
# 2) Join with airports from ourairports using word similitude or something like that
#
# [Understanding _CODE from airports](https://www3.gobiernodecanarias.org/aplicaciones/appsistac/activos-semanticos/codelists/codelists/ISTAC/CL_AEROPUERTOS/01.004/detail)

# %% [markdown]
# I think I can do all I did (selecting only airports) with the API XD, with the "granularity" option, tomorrow ill check

# %%
# Rest of/Remain of AEROPUERTO_ESCALA#en have "_O" at the end of their code
df_f = df.loc[~df['AEROPUERTO_ESCALA_CODE'].str.endswith('_O')]

# Delete entries with the whole country
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^[A-Z]{2}$', na=False)]

# Delete autonomous communities (Their code is like ES[0-9][0-9]) 
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^ES[0-9]{2}$', na=False)]

# Delete sum of entire island
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^ES70[0-9]$', na=False)]

# Delete sum of all autonomous communities and sum of all islands
df_f = df_f.loc[~((df_f['AEROPUERTO_ESCALA_CODE'] == 'ES_XES70') | (df_f['AEROPUERTO_ESCALA_CODE'] == 'ES70'))]

# %%
df_f
# Out:
#         SERVICIO_AEREO#en SERVICIO_AEREO_CODE  MEDIDAS#en MEDIDAS_CODE  \
# 280            Commercial          COMMERCIAL  Passengers    PASAJEROS
# 281            Commercial          COMMERCIAL  Passengers    PASAJEROS
# 282            Commercial          COMMERCIAL  Passengers    PASAJEROS
# 283            Commercial          COMMERCIAL  Passengers    PASAJEROS
# 284            Commercial          COMMERCIAL  Passengers    PASAJEROS
# ...                   ...                 ...         ...          ...
# 2963515         Scheduled           SCHEDULED  Passengers    PASAJEROS
# 2963516         Scheduled           SCHEDULED  Passengers    PASAJEROS
# 2963517         Scheduled           SCHEDULED  Passengers    PASAJEROS
# 2963518         Scheduled           SCHEDULED  Passengers    PASAJEROS
# 2963519         Scheduled           SCHEDULED  Passengers    PASAJEROS
#
#         MOVIMIENTO_AERONAVE#en MOVIMIENTO_AERONAVE_CODE TIME_PERIOD#en  \
# 280                      Total                       _T        02/2014
# 281                      Total                       _T        03/2014
# 282                      Total                       _T        04/2014
# 283                      Total                       _T        05/2014
# 284                      Total                       _T        06/2014
# ...                        ...                      ...            ...
# 2963515                  Total                       _T        10/2013
# 2963516                  Total                       _T        11/2013
# 2963517                  Total                       _T        12/2013
# 2963518                  Total                       _T           2013
# 2963519                  Total                       _T        01/2014
#
#         TIME_PERIOD_CODE      AEROPUERTO_BASE#en AEROPUERTO_BASE_CODE  \
# 280             2014-M02  Tenerife Norte Airport              ES_GCXO
# 281             2014-M03  Tenerife Norte Airport              ES_GCXO
# 282             2014-M04  Tenerife Norte Airport              ES_GCXO
# 283             2014-M05  Tenerife Norte Airport              ES_GCXO
# 284             2014-M06  Tenerife Norte Airport              ES_GCXO
# ...                  ...                     ...                  ...
# 2963515         2013-M10       Lanzarote Airport              ES_GCRR
# 2963516         2013-M11       Lanzarote Airport              ES_GCRR
# 2963517         2013-M12       Lanzarote Airport              ES_GCRR
# 2963518             2013       Lanzarote Airport              ES_GCRR
# 2963519         2014-M01       Lanzarote Airport              ES_GCRR
#
#                      AEROPUERTO_ESCALA#en AEROPUERTO_ESCALA_CODE  OBS_VALUE  \
# 280      Nouadhibou International Airport                MR_GQPP        NaN
# 281      Nouadhibou International Airport                MR_GQPP        NaN
# 282      Nouadhibou International Airport                MR_GQPP        NaN
# 283      Nouadhibou International Airport                MR_GQPP        NaN
# 284      Nouadhibou International Airport                MR_GQPP        NaN
# ...                                   ...                    ...        ...
# 2963515              Malmö Sturup Airport                SE_ESMS        NaN
# 2963516              Malmö Sturup Airport                SE_ESMS        NaN
# 2963517              Malmö Sturup Airport                SE_ESMS        NaN
# 2963518              Malmö Sturup Airport                SE_ESMS        NaN
# 2963519              Malmö Sturup Airport                SE_ESMS        NaN
#
#         ESTADO_OBSERVACION#en ESTADO_OBSERVACION_CODE  \
# 280                       NaN                     NaN
# 281                       NaN                     NaN
# 282                       NaN                     NaN
# 283                       NaN                     NaN
# 284                       NaN                     NaN
# ...                       ...                     ...
# 2963515                   NaN                     NaN
# 2963516                   NaN                     NaN
# 2963517                   NaN                     NaN
# 2963518                   NaN                     NaN
# 2963519                   NaN                     NaN
#
#          CONFIDENCIALIDAD_OBSERVACION#en
# 280                                  NaN
# 281                                  NaN
# 282                                  NaN
# 283                                  NaN
# 284                                  NaN
# ...                                  ...
# 2963515                              NaN
# 2963516                              NaN
# 2963517                              NaN
# 2963518                              NaN
# 2963519                              NaN
#
# [2005920 rows x 16 columns]

# %%
df_f['AEROPUERTO_ESCALA#en'].sort_values().unique()
# Out:
# array(['A Coruña Airport', 'Aalborg Airport', 'Aarhus Airport',
#        'Aberdeen Dyce Airport', 'Adolfo Suárez Madrid-Barajas Airport',
#        'Al Massira Airport', 'Alicante International Airport',
#        'Amsterdam Airport Schiphol',
#        'Amílcar Cabral International Airport', 'Asturias Airport',
#        'Banjul International Airport', 'Barcelona International Airport',
#        'Belfast International Airport', 'Bergen Airport Flesland',
#        'Berlin-Schönefeld Airport', 'Berlin-Tegel Airport',
#        'Bilbao Airport', 'Billund Airport',
#        'Birmingham International Airport',
#        'Blackpool International Airport', 'Bodô Airport',
#        'Bologna Guglielmo Marconi Airport', 'Bordeaux-Mérignac Airport',
#        'Borlange Airport', 'Boryspil International Airport',
#        'Bournemouth Airport', 'Bremen Airport', 'Brest Bretagne Airport',
#        'Bristol Airport', 'Brussels Airport',
#        'Brussels South Charleroi Airport',
#        'Budapest Liszt Ferenc International Airport',
#        'Cardiff International Airport',
#        'Charles de Gaulle International Airport', 'Cologne Bonn Airport',
#        'Copenhagen Kastrup Airport', 'Copernicus Wroclaw Airport',
#        'Cork Airport', 'Dakhla Airport', 'Deauville-Saint-Gatien Airport',
#        'Domodedovo International Airport', 'Dortmund Airport',
#        'Dresden Airport', 'Dublin Airport', 'Durham Tees Valley Airport',
#        'Düsseldorf Airport', 'East Midlands Airport', 'Edinburgh Airport',
#        'Eelde Airport', 'Eindhoven Airport', 'Erfurt Airport',
#        'EuroAirport Basel-Mulhouse-Freiburg Airport',
#        'Exeter International Airport', 'Faro Airport',
#        'Federico Garcia Lorca Airport', 'Foreign',
#        'Francisco de Sá Carneiro Airport', 'Frankfurt am Main Airport',
#        'Frankfurt-Hahn Airport', 'Friedrichshafen Airport',
#        'Fuerteventura Airport', 'Gdansk Lech Walesa Airport',
#        'Geneva Cointrin International Airport', 'Girona Airport',
#        'Glasgow International Airport', 'Glasgow Prestwick Airport',
#        'Gothenburg-Landvetter Airport', 'Gran Canaria Airport',
#        'Graz Airport', 'Halmstad Airport', 'Hamburg Airport',
#        'Hannover Airport', 'Harstad/Narvik Airport, Evenes',
#        'Hassan I Airport', 'Haugesund Airport', 'Helsinki Vantaa Airport',
#        'Henri Coanda International Airport', 'Hierro Airport',
#        'Humberside Airport', 'Humberto Delgado Airport',
#        'Il Caravaggio International Airport',
#        'Ireland West Knock Airport', 'Jerez Airport',
#        'João Paulo II Airport', 'Jönköping Airport', 'Kalmar Airport',
#        'Karlsruhe Baden-Baden Airport', 'Karlstad Airport',
#        'Kassel-Calden Airport', 'Katowice International Airport',
#        'Keflavik International Airport',
#        'Kraków John Paul II International Airport',
#        'Kristiansand Airport', 'Kuopio Airport', 'La Gomera Airport',
#        'La Palma Airport', 'Lanzarote Airport', 'Leeds Bradford Airport',
#        'Leipzig/Halle Airport', 'Lennart Meri Tallinn Airport',
#        'Leon Airport', 'Leonardo da Vinci-Fiumicino Airport',
#        'Lille-Lesquin Airport', 'Linz Hörsching Airport',
#        'Liverpool John Lennon Airport', 'Liège Airport',
#        'London Gatwick Airport', 'London Heathrow Airport',
#        'London Luton Airport', 'London Stansted Airport', 'Luleå Airport',
#        'Luxembourg-Findel International Airport',
#        'Lyon Saint-Exupéry Airport',
#        'Léopold Sédar Senghor International Airport',
#        'M. R. Štefánik Airport', 'Maastricht Aachen Airport',
#        'Madeira Airport', 'Malmö Sturup Airport',
#        'Malpensa International Airport', 'Manchester Airport',
#        'Marseille Provence Airport', 'Memmingen Allgau Airport',
#        'Menara Airport', 'Metz-Nancy-Lorraine Airport', 'Modlin Airport',
#        'Mohammed V International Airport', 'Molde Airport',
#        'Moss Airport, Rygge', 'Munich Airport', 'Málaga Airport',
#        'Münster Osnabrück Airport', 'Nantes Atlantique Airport',
#        'Naples International Airport', 'Newcastle Airport',
#        'Norrköping Airport', 'Norwich International Airport',
#        'Nouadhibou International Airport',
#        'Nouakchott-Oumtounsy International Airport', 'Nuremberg Airport',
#        'Oslo Gardermoen Airport', 'Ostend-Bruges International Airport',
#        'Oulu Airport', 'Paderborn Lippstadt Airport',
#        'Palma De Mallorca Airport', 'Pamplona Airport',
#        'Paris Beauvais Tillé Airport', 'Paris-Orly Airport',
#        'Pisa International Airport', 'Poznan-Lawica Airport',
#        'Praia International Airport', 'Pulkovo Airport', 'Rabil Airport',
#        'Riga International Airport',
#        'Robin Hood Doncaster Sheffield Airport', 'Rostock-Laage Airport',
#        'Rotterdam The Hague Airport', 'Saarbrücken Airport',
#        'Salamanca Airport', 'Salzburg Airport',
#        'Sandefjord Airport, Torp', 'Santander Airport',
#        'Santiago de Compostela Airport', 'Sevilla Airport',
#        'Shannon Airport', 'Sheremetyevo International Airport',
#        'Simón Bolívar International Airport', 'Southend Airport',
#        'Spain (Canary Islands excluded)', 'Stavanger Airport Sola',
#        'Stockholm Skavsta Airport', 'Stockholm-Arlanda Airport',
#        'Stuttgart Airport', 'Sundsvall-Härnösand Airport',
#        'Tampere-Pirkkala Airport', 'Tenerife Norte Airport',
#        'Tenerife South Airport', 'Toulouse-Blagnac Airport',
#        "Treviso-Sant'Angelo Airport", 'Tromsô Airport',
#        'Trondheim Airport Vèrnes', 'Turku Airport', 'Umeå Airport',
#        'Vaasa Airport', 'Valencia Airport', 'Valladolid Airport',
#        'Verona Villafranca Airport', 'Vienna International Airport',
#        'Vigo Airport', 'Vilnius International Airport',
#        'Vitoria/Foronda Airport', 'Vnukovo International Airport',
#        'Václav Havel Airport Prague', 'Växjö Kronoberg Airport',
#        'Warsaw Chopin Airport', 'Weeze Airport', 'Zaragoza Air Base',
#        'Zweibrücken Airport', 'Zürich Airport', 'Ålesund Airport',
#        'Örebro Airport'], dtype=object)

# %%
istac_airports = df['AEROPUERTO_ESCALA#en'].sort_values().unique()

# %%
airport_csv = pd.read_csv('airports.csv')
