# %%
"""
This notebook creates the dimension tables of our data model. This tables are not expected to change, so we only create them once using this notebook
and in theory it should never be executed again unless the ISTAC changes something like a code or the name of some airport
"""
# Out:
# '\nThis notebook creates the dimension tables of our data model. This tables are not expected to change, so we only create them once using this notebook\nand in theory it should never be executed again\n'

# %%
import pandas as pd
import utils as u

# %% [markdown]
# # Airport

# %%
url_passengers = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000001/~latest.csv?lang=en"
url_gm = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000002/~latest.csv"
url_op = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000003/~latest.csv"

# %%
data_t = pd.read_csv(u.get_data_from_API_call(url_passengers))

# %%
df = data_t.copy(deep=True)

# %%
df.drop(columns=df.columns[df.columns.str.endswith('#es')], inplace=True)

# %%
df['AEROPUERTO_ESCALA_CODE']
# Out:
# 0               CV
# 1               CV
# 2               CV
# 3               CV
# 4               CV
#             ...
# 2963515    SE_ESMS
# 2963516    SE_ESMS
# 2963517    SE_ESMS
# 2963518    SE_ESMS
# 2963519    SE_ESMS
# Name: AEROPUERTO_ESCALA_CODE, Length: 2963520, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2963520 entries, 0 to 2963519
# Data columns (total 16 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   SERVICIO_AEREO#en                object
#  1   SERVICIO_AEREO_CODE              object
#  2   MEDIDAS#en                       object
#  3   MEDIDAS_CODE                     object
#  4   MOVIMIENTO_AERONAVE#en           object
#  5   MOVIMIENTO_AERONAVE_CODE         object
#  6   TIME_PERIOD#en                   object
#  7   TIME_PERIOD_CODE                 object
#  8   AEROPUERTO_BASE#en               object
#  9   AEROPUERTO_BASE_CODE             object
#  10  AEROPUERTO_ESCALA#en             object
#  11  AEROPUERTO_ESCALA_CODE           object
#  12  OBS_VALUE                        float64
#  13  ESTADO_OBSERVACION#en            object
#  14  ESTADO_OBSERVACION_CODE          object
#  15  CONFIDENCIALIDAD_OBSERVACION#en  float64
# dtypes: float64(2), object(14)
# memory usage: 361.8+ MB

# %% [markdown]
# Steps to getting the airports right:
# 1) Delete countries, autonomous communities and "Rest of"/"Remain of"
# 2) Join with airports from ourairports using word similitude or something like that
#
# [Understanding _CODE from airports](https://www3.gobiernodecanarias.org/aplicaciones/appsistac/activos-semanticos/codelists/codelists/ISTAC/CL_AEROPUERTOS/01.004/detail)

# %% [markdown]
# I think I can do all I did (selecting only airports) with the API, with the "granularity" option, tomorrow ill check
#
# Hello, it is tomorrow, it can not be done, I tried

# %%
# Extract countries
countries = df.loc[df['AEROPUERTO_ESCALA_CODE'].str.match(r'^[A-Z]{2}$', na=False), ['AEROPUERTO_ESCALA#en', 'AEROPUERTO_ESCALA_CODE']]
countries.drop_duplicates(inplace=True)
countries.rename({'AEROPUERTO_ESCALA#en': 'CountryName', 'AEROPUERTO_ESCALA_CODE': 'iso_country'}, inplace=True, axis=1)

# %%
countries
# Out:
#                                              CountryName iso_country
# 0                                             Cabo Verde          CV
# 3360                                             Iceland          IS
# 9240                                              France          FR
# 15120                                             Gambia          GM
# 16240                                        Netherlands          NL
# 19320                                            Belgium          BE
# 21280                                            Morocco          MA
# 23520                                             Norway          NO
# 24360                                            Ukraine          UA
# 28840                                          Lithuania          LT
# 29400                                           Slovakia          SK
# 31080                                            Germany          DE
# 35840                                            Austria          AT
# 43400  United Kingdom of Great Britain and Northern I...          GB
# 43680                                              Italy          IT
# 44800                                           Portugal          PT
# 48160                                            Romania          RO
# 49560                                             Latvia          LV
# 50680                                              Spain          ES
# 52080                                            Ireland          IE
# 52360                                         Mauritania          MR
# 53480                                            Finland          FI
# 54040                                            Hungary          HU
# 58240                                             Poland          PL
# 59640                                            Estonia          EE
# 61040                                          Venezuela          VE
# 61880                                     Czech Republic          CZ
# 62160                                            Senegal          SN
# 62720                                            Denmark          DK
# 64120                                 Russian Federation          RU
# 68320                                         Luxembourg          LU
# 68600                                        Switzerland          CH
# 69440                                             Sweden          SE

# %%
# Rest of/Remain of AEROPUERTO_ESCALA#en have "_O" at the end of their code
df_f = df.loc[~df['AEROPUERTO_ESCALA_CODE'].str.endswith('_O')]

# Delete entries with the whole country
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^[A-Z]{2}$', na=False)]

# Delete autonomous communities (Their code is like ES[0-9][0-9]) 
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^ES[0-9]{2}$', na=False)]

# Delete sum of entire island
df_f = df_f.loc[~df_f['AEROPUERTO_ESCALA_CODE'].str.match(r'^ES70[0-9]$', na=False)]

# Delete sum of all autonomous communities and sum of all islands
df_f = df_f.loc[~((df_f['AEROPUERTO_ESCALA_CODE'] == 'ES_XES70') | (df_f['AEROPUERTO_ESCALA_CODE'] == 'ES70') | (df_f['AEROPUERTO_ESCALA_CODE'] == 'FOREIGN'))]

# %%
df_f.loc[~df_f['AEROPUERTO_ESCALA#en'].str.endswith('Airport', na=False), 'AEROPUERTO_ESCALA#en'].unique()
# Out:
# array(['Trondheim Airport Vèrnes', 'Zaragoza Air Base',
#        'Sandefjord Airport, Torp', 'Harstad/Narvik Airport, Evenes',
#        'Stavanger Airport Sola', 'Amsterdam Airport Schiphol',
#        'Václav Havel Airport Prague', 'Bergen Airport Flesland',
#        'Moss Airport, Rygge'], dtype=object)

# %%
istac_airports = df_f[['AEROPUERTO_ESCALA#en', 'AEROPUERTO_ESCALA_CODE']].copy(deep=True)

# %%
istac_airports.drop_duplicates(inplace=True)

# %%
istac_airports
# Out:
#                               AEROPUERTO_ESCALA#en AEROPUERTO_ESCALA_CODE
# 280               Nouadhibou International Airport                MR_GQPP
# 560                               Brussels Airport                BE_EBBR
# 840                     Durham Tees Valley Airport                GB_EGNV
# 1120                                Dublin Airport                IE_EIDW
# 1400                       Växjö Kronoberg Airport                SE_ESMX
# ...                                            ...                    ...
# 80640             Francisco de Sá Carneiro Airport                PT_LPPR
# 80920                          Zweibrücken Airport                DE_EDRZ
# 81480                                 Vigo Airport                ES_LEVX
# 81760  Léopold Sédar Senghor International Airport                SN_GOOY
# 82040                         Malmö Sturup Airport                SE_ESMS
#
# [198 rows x 2 columns]

# %%
istac_airports['ident'] = istac_airports['AEROPUERTO_ESCALA_CODE'].str[3:]

# %%
airport_csv = pd.read_csv('airports.csv')

# %%
airport_csv = airport_csv.merge(countries, on='iso_country')

# %%
join = istac_airports.merge(airport_csv, on='ident', suffixes=("l", "r"))

# %%
join
# Out:
#                             AEROPUERTO_ESCALA#en AEROPUERTO_ESCALA_CODE ident  \
# 0               Nouadhibou International Airport                MR_GQPP  GQPP
# 1                               Brussels Airport                BE_EBBR  EBBR
# 2                     Durham Tees Valley Airport                GB_EGNV  EGNV
# 3                                 Dublin Airport                IE_EIDW  EIDW
# 4                        Växjö Kronoberg Airport                SE_ESMX  ESMX
# ..                                           ...                    ...   ...
# 189             Francisco de Sá Carneiro Airport                PT_LPPR  LPPR
# 190                          Zweibrücken Airport                DE_EDRZ  EDRZ
# 191                                 Vigo Airport                ES_LEVX  LEVX
# 192  Léopold Sédar Senghor International Airport                SN_GOOY  GOOY
# 193                         Malmö Sturup Airport                SE_ESMS  ESMS
#
#        id            type                                         name  \
# 0    3138  medium_airport             Nouadhibou International Airport
# 1    2155   large_airport                             Brussels Airport
# 2    2449  medium_airport               Teesside International Airport
# 3    2533   large_airport                               Dublin Airport
# 4    2672  medium_airport                      Växjö Kronoberg Airport
# ..    ...             ...                                          ...
# 189  4459   large_airport             Francisco de Sá Carneiro Airport
# 190  2269   small_airport                          Zweibrücken Airport
# 191  4046  medium_airport                                 Vigo Airport
# 192  3125  medium_airport  Léopold Sédar Senghor International Airport
# 193  2669  medium_airport                         Malmö Sturup Airport
#
#      latitude_deg  longitude_deg  elevation_ft continent  ...  \
# 0       20.933100     -17.030001          24.0        AF  ...
# 1       50.901402       4.484440         175.0        EU  ...
# 2       54.509201      -1.429410         120.0        EU  ...
# 3       53.428713      -6.262121         242.0        EU  ...
# 4       56.929100      14.728000         610.0        EU  ...
# ..            ...            ...           ...       ...  ...
# 189     41.248100      -8.681390         228.0        EU  ...
# 190     49.209400       7.400560        1132.0        EU  ...
# 191     42.231800      -8.626770         856.0        EU  ...
# 192     14.739700     -17.490200          85.0        AF  ...
# 193     55.535564      13.376327         236.0        EU  ...
#
#            municipality scheduled_service icao_code iata_code gps_code  \
# 0            Nouadhibou               yes      GQPP       NDB     GQPP
# 1              Zaventem               yes      EBBR       BRU     EBBR
# 2    Darlington, Durham               yes      EGNV       MME     EGNV
# 3                Dublin               yes      EIDW       DUB     EIDW
# 4                 Växjö               yes      ESMX       VXO     ESMX
# ..                  ...               ...       ...       ...      ...
# 189               Porto               yes      LPPR       OPO     LPPR
# 190         Zweibrücken                no      EDRZ       ZQW     EDRZ
# 191                Vigo               yes      LEVX       VGO     LEVX
# 192               Dakar                no      GOOY       DKR     GOOY
# 193               Malmö               yes      ESMS       MMX     ESMS
#
#     local_code                                          home_link  \
# 0          NaN                                                NaN
# 1          NaN                  http://www.brusselsairport.be/en/
# 2          NaN             https://www.teessideinternational.com/
# 3          NaN                      http://www.dublinairport.com/
# 4          NaN                                                NaN
# ..         ...                                                ...
# 189        NaN  http://www.ana.pt/en-US/Aeroportos/porto/Porto...
# 190        NaN                         http://www.edrz-airport.de
# 191        NaN                   https://www.aena.es/en/vigo.html
# 192        NaN                      http://www.aeroportdakar.com/
# 193        NaN                     http://www.swedavia.com/malmo/
#
#                                         wikipedia_link  \
# 0    https://en.wikipedia.org/wiki/Nouadhibou_Inter...
# 1       https://en.wikipedia.org/wiki/Brussels_Airport
# 2    https://en.wikipedia.org/wiki/Teesside_Interna...
# 3         https://en.wikipedia.org/wiki/Dublin_Airport
# 4    https://en.wikipedia.org/wiki/V%C3%A4xj%C3%B6_...
# ..                                                 ...
# 189  https://en.wikipedia.org/wiki/Francisco_S%C3%A...
# 190  https://en.wikipedia.org/wiki/Zweibr%C3%BCcken...
# 191  https://en.wikipedia.org/wiki/Vigo-Peinador_Ai...
# 192  https://en.wikipedia.org/wiki/Dakar-Yoff-L%C3%...
# 193   https://en.wikipedia.org/wiki/Malm%C3%B6_Airport
#
#                                               keywords  \
# 0                                                  NaN
# 1                    Brussels National, Zaventem, EBMB
# 2    Durham Tees Valley Airport, RAF Middleton St G...
# 3                           Aerfort Bhaile Átha Cliath
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                               Yoff
# 193                                                NaN
#
#                                            CountryName
# 0                                           Mauritania
# 1                                              Belgium
# 2    United Kingdom of Great Britain and Northern I...
# 3                                              Ireland
# 4                                               Sweden
# ..                                                 ...
# 189                                           Portugal
# 190                                            Germany
# 191                                              Spain
# 192                                            Senegal
# 193                                             Sweden
#
# [194 rows x 22 columns]

# %% [markdown]
# Only two missing airports, I can input them by hand

# %%
print(f"Mising airports: {len(istac_airports['AEROPUERTO_ESCALA#en'].unique()) - len(join['AEROPUERTO_ESCALA#en'].unique())}")
missing_airports = set(istac_airports['AEROPUERTO_ESCALA#en'].unique()) - set(join['AEROPUERTO_ESCALA#en'].unique())
print(f"Missing airports: {missing_airports}")
# Out:
# Mising airports: 2
# Missing airports: {'Berlin-Tegel Airport', 'Robin Hood Doncaster Sheffield Airport'}

# %%
result_df = join[['AEROPUERTO_ESCALA#en', 'AEROPUERTO_ESCALA_CODE', 'latitude_deg', 'longitude_deg','iso_country', 'CountryName']].copy(deep=True)
result_df.rename({'iso_country': 'CountryCode', 'AEROPUERTO_ESCALA#en': 'AirportName', 
                  'latitude_deg': 'Latitude', 'longitude_deg': 'Longitude', 
                  'country': 'CountryName', 'AEROPUERTO_ESCALA_CODE': 'AirportCode'}, axis=1, inplace=True)

# %%
result_df['AirportId'] = result_df.index

# %%
result_df.to_csv('Airport.csv', index=False)
result_df
# Out:
#                                      AirportName AirportCode   Latitude  \
# 0               Nouadhibou International Airport     MR_GQPP  20.933100
# 1                               Brussels Airport     BE_EBBR  50.901402
# 2                     Durham Tees Valley Airport     GB_EGNV  54.509201
# 3                                 Dublin Airport     IE_EIDW  53.428713
# 4                        Växjö Kronoberg Airport     SE_ESMX  56.929100
# ..                                           ...         ...        ...
# 189             Francisco de Sá Carneiro Airport     PT_LPPR  41.248100
# 190                          Zweibrücken Airport     DE_EDRZ  49.209400
# 191                                 Vigo Airport     ES_LEVX  42.231800
# 192  Léopold Sédar Senghor International Airport     SN_GOOY  14.739700
# 193                         Malmö Sturup Airport     SE_ESMS  55.535564
#
#      Longitude CountryCode                                        CountryName  \
# 0   -17.030001          MR                                         Mauritania
# 1     4.484440          BE                                            Belgium
# 2    -1.429410          GB  United Kingdom of Great Britain and Northern I...
# 3    -6.262121          IE                                            Ireland
# 4    14.728000          SE                                             Sweden
# ..         ...         ...                                                ...
# 189  -8.681390          PT                                           Portugal
# 190   7.400560          DE                                            Germany
# 191  -8.626770          ES                                              Spain
# 192 -17.490200          SN                                            Senegal
# 193  13.376327          SE                                             Sweden
#
#      AirportId
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ..         ...
# 189        189
# 190        190
# 191        191
# 192        192
# 193        193
#
# [194 rows x 7 columns]

# %% [markdown]
# # Territory, AircraftMovement, AirService

# %%
url = "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00017A_000013/~latest.csv?lang=en"

# %%
data = pd.read_csv(u.get_data_from_API_call(url))

# %%
#data.loc[data['TERRITORIO#en'] == "Gran Canaria"].drop(columns=data.columns[(data.columns.str.endswith("#es")) | (data.columns.str.endswith("#en"))]).to_csv('borrar.csv', index=False)

# %%
df = data.copy(deep=True)

# %%
df_terr = pd.concat([df[['TERRITORIO_CODE', 'TERRITORIO#en']], df[['AEROPUERTO_ESCALA_CODE', 'AEROPUERTO_ESCALA#en']].rename({'AEROPUERTO_ESCALA#en': 'TERRITORIO#en', 'AEROPUERTO_ESCALA_CODE': 'TERRITORIO_CODE'}, axis=1)]).drop_duplicates()

df_terr.reset_index(inplace=True, drop=True)

# Remove "Total", "Foreign and Spain (Canary Islands excluded)", "Spain"
df_terr = df_terr.loc[~df_terr['TERRITORIO_CODE'].isin(["_T_XES70", "ES", "_T"])]

df_terr['TerritoryId'] = df_terr.index

df_terr.rename({'TERRITORIO_CODE': 'TerritoryCode', 'TERRITORIO#en': 'TerritoryName'}, inplace=True, axis=1)

df_terr = df_terr[['TerritoryId', 'TerritoryCode', 'TerritoryName']]

df_terr.to_csv('Final_Territory.csv', index=False)

# %%
df_am = df[['MOVIMIENTO_AERONAVE_CODE', 'MOVIMIENTO_AERONAVE#en']].drop_duplicates().reset_index(drop=True)

df_am['AircraftMovementId'] = df_am.index

df_am.rename({'MOVIMIENTO_AERONAVE_CODE': 'AircraftMovementCode', 'MOVIMIENTO_AERONAVE#en': 'AircraftMovement'}, axis=1, inplace=True)

df_am = df_am[['AircraftMovementId', 'AircraftMovementCode', 'AircraftMovement']]

df_am.to_csv('Final_AircraftMovement.csv', index=False)

# %%
df_as = df[['SERVICIO_AEREO_CODE', 'SERVICIO_AEREO#en']].drop_duplicates().reset_index(drop=True)

df_as['AirServiceId'] = df_as.index

df_as.rename({'SERVICIO_AEREO_CODE': 'AirServiceCode', 'SERVICIO_AEREO#en': 'AirService'}, axis=1, inplace=True)

df_as = df_as[['AirServiceId', 'AirServiceCode','AirService', ]]

df_as.to_csv('Final_AirService.csv', index=False)
